# %%
import tbapy
import pandas as pd
from itertools import permutations, combinations
import os 
import collections

from bs4 import BeautifulSoup
import requests
import json
import time
import random
import urllib.request

# %%
tbakey = os.environ.get('tbakey')
tba = tbapy.TBA(tbakey)

# %%
event = '2023oncmp2'

# %%
# Out:
# [Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1241', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'General Motors/Pratt & Whitney Canada/Johnston Industrial Plastics Limited/CSC/Zerox/DBG Canada Limited/Symcor/Rev Creations/Rakla Tires/Click N Print/Trans Canada/99Cent Depot/Dreams Convention Center/Studica/City of Mississauga/Peel District School Board&Rick Hansen S.S', 'nickname': 'THEORY6', 'postal_code': 'L5V 1N6', 'rookie_year': 2004, 'school_name': 'Rick Hansen S.S', 'state_prov': 'Ontario', 'team_number': 1241, 'website': 'http://www.theory6.ca'}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1310', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Toronto District School Board/Runnymede CI/Optimist International/Microsoft/Outlook Promotions/The Kingsway Digital Company/KPM Power&Runnymede Collegiate Institute', 'nickname': 'Runnymede Robotics', 'postal_code': 'M6S 4A3', 'rookie_year': 2004, 'school_name': 'Runnymede Collegiate Institute', 'state_prov': 'Ontario', 'team_number': 1310, 'website': 'http://www.team1310.ca'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1325', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Pacline Overhead Conveyors/Actemium/Yamana Gold Inc./MHI Canada Aerospace/General Motors/Hatch/Amazon/Weston Forest Products/MindShare Workspace/Sable Metal Manufacturing/Agora Manufacturing/Nye Manufacturing/Thompson Centres/IMAX/Westburne/Royal Bank of Canada&Family/Community', 'nickname': 'Inverse Paradox', 'postal_code': 'L5R 3N9 ', 'rookie_year': 2004, 'school_name': 'Family/Community', 'state_prov': 'Ontario', 'team_number': 1325, 'website': 'http://www.team1325.com/'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1334', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'HDSB Technological Education (TE)/Hatch&Oakville-Trafalgar High School', 'nickname': 'Red Devils', 'postal_code': 'L6J 3L6', 'rookie_year': 2004, 'school_name': 'Oakville-Trafalgar High School', 'state_prov': 'Ontario', 'team_number': 1334, 'website': 'http://www.1334.ca'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1360', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Gyptech/TC Energy/Studica/Ford Motor Company/Desjardins Foundation/Pratt & Whitney Canada/Rockwell Automation/Magna/Woodbridge Foam Corporation/Town of Oakville/Oakville Community Foundation&Oakville Community FIRST Robotics', 'nickname': 'Orbit Robotics', 'postal_code': 'L6J 3H1', 'rookie_year': 2004, 'school_name': 'Oakville Community FIRST Robotics', 'state_prov': 'Ontario', 'team_number': 1360, 'website': 'https://www.1360.ca'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1374', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Halton District School Board - Technological Education (HDSB TE)/Hatch/Sinn Development&OAKVILLE TRAFALGAR HIGH SCHOOL', 'nickname': 'Amped Up', 'postal_code': 'l6j 3l6', 'rookie_year': 2004, 'school_name': 'OAKVILLE TRAFALGAR HIGH SCHOOL', 'state_prov': 'Ontario', 'team_number': 1374, 'website': 'http://www.1374.ca'}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc188', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'EM Dynamics/DevCycle/CGI/Forge Automation/Life Sciences Ontario/Toronto District School Board&Woburn Collegiate Institute', 'nickname': 'Blizzard', 'postal_code': 'M1G 3M3', 'rookie_year': 1998, 'school_name': 'Woburn Collegiate Institute', 'state_prov': 'Ontario', 'team_number': 188, 'website': 'http://www.team188.com'}),
#  Team({'address': None, 'city': 'Stoney Creek', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2056', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'ArcelorMittal Dofasco/GM/HWDSB&Orchard Park Secondary School', 'nickname': 'OP Robotics', 'postal_code': 'L8E 4M5', 'rookie_year': 2007, 'school_name': 'Orchard Park Secondary School', 'state_prov': 'Ontario', 'team_number': 2056, 'website': 'http://www.2056.ca'}),
#  Team({'address': None, 'city': 'Burlington', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2200', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Arcelor Mittal Dofasco Hamilton/Almex Group/Shape Process Automation/Wera Tools/Pratt and Whitney Canada/Burlington Auto Works/Custom Paint & Silk Screen Inc./Studica Canada/Full Fusion Welding/Pacsys /Advent Tech /Irving Consumer&M.M. Robinson High School', 'nickname': 'MMRambotics', 'postal_code': 'L7P 3N9', 'rookie_year': 2007, 'school_name': 'M.M. Robinson High School', 'state_prov': 'Ontario', 'team_number': 2200, 'website': 'http://www.mmrambotics.com'}),
#  Team({'address': None, 'city': 'Burlington', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2386', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Arcelor Mittal Dofasco/Halton District School Board/Pathways/BMP Metals/Bentley Systems/FeedRite Automation/Hatch/Studica/iCubed/Powerhouse Controls/Taylor Steel/B & D Steel/Penta Properties/Sew 'n Stuff/Klearview&Burlington Central High School", 'nickname': 'Trojans', 'postal_code': 'L7S 1K4', 'rookie_year': 2008, 'school_name': 'Burlington Central High School', 'state_prov': 'Ontario', 'team_number': 2386, 'website': 'https://www.bchrobotics.com'}),
#  Team({'address': None, 'city': 'Guelph', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2609', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Synnex/Linamar Corporation/Michelin/Wellington Catholic School Board&Our Lady of Lourdes CHS', 'nickname': 'BeaverworX', 'postal_code': 'N1H 5H7', 'rookie_year': 2008, 'school_name': 'Our Lady of Lourdes CHS', 'state_prov': 'Ontario', 'team_number': 2609, 'website': 'http://Beaverworx.ca'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4015', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': '&St. Joseph Secondary School', 'nickname': 'Jag', 'postal_code': 'L5V2B9', 'rookie_year': 2012, 'school_name': 'St. Joseph Secondary School', 'state_prov': 'Ontario', 'team_number': 4015, 'website': 'http://www.firstinspires.org/'}),
#  Team({'address': None, 'city': 'Aurora', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4343', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Magna/York Catholic District School Board/TD Synnex & Dell Technologies/Clover Tool Manufacturing Limited/STEM Minds/Town of Aurora/Home Hardware/Rotary Club of Aurora/TACC Developments/Staples - Solution Shop /Antoniette Catenacci (Haute Couture)/BALLUFF/Irwin Industrial/Optimist Club of Aurora/Princess Auto&St Maximilian Kolbe Catholic High School', 'nickname': 'MaxTech', 'postal_code': 'L4G1J5', 'rookie_year': 2012, 'school_name': 'St Maximilian Kolbe Catholic High School', 'state_prov': 'Ontario', 'team_number': 4343, 'website': 'http://4343.ca'}),
#  Team({'address': None, 'city': 'Milton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4992', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Halton District School Board Technical Education, Pathways and SHSM/Craig Kielburger Secondary School Hospitality&Craig Kielburger Secondary School', 'nickname': 'Sparbotics', 'postal_code': 'L9T 7V8', 'rookie_year': 2014, 'school_name': 'Craig Kielburger Secondary School', 'state_prov': 'Ontario', 'team_number': 4992, 'website': 'http://www.4992.ca'}),
#  Team({'address': None, 'city': 'Hamilton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5406', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'HWCDSB/John Deere Canada/HATCH/Arcelor-Mittal Dofasco/Jantz Canada/Rev Robotics&Bishop Ryan Catholic Secondary School', 'nickname': 'Celt-X', 'postal_code': 'L0R1P0', 'rookie_year': 2015, 'school_name': 'Bishop Ryan Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 5406, 'website': 'https://5406.ca'}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6135', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Milwaukee Tool/The Intuitive Foundation /Ryver/Stantec/Toronto District School Board, Bloor CI&Bloor C.I.', 'nickname': 'Arctos', 'postal_code': 'M6H1M9', 'rookie_year': 2016, 'school_name': 'Bloor C.I.', 'state_prov': 'Ontario', 'team_number': 6135, 'website': 'https://arctos6135.com'}),
#  Team({'address': None, 'city': 'Scarborough', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6140', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Microsoft Corporation/RBC Wealth Management PH & N Group/Enbridge Gas Team Sponsorship Grant/Argosy Hardship Grant/TORONTO CATHOLIC DISTRICT SCHOOL BOARD - 21st Century Learning&St. Mother Teresa Catholic Academy', 'nickname': "SMT Titans - The 'Tita'BOTS", 'postal_code': 'M1B 3G5', 'rookie_year': 2016, 'school_name': 'St. Mother Teresa Catholic Academy', 'state_prov': 'Ontario', 'team_number': 6140, 'website': 'http://www.twitter.com/smtrobotics'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6378', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'emami/Peel District School Board &Stephen Lewis Secondary School', 'nickname': 'LYNX', 'postal_code': 'L5M 7E6', 'rookie_year': 2017, 'school_name': 'Stephen Lewis Secondary School', 'state_prov': 'Ontario', 'team_number': 6378, 'website': 'http://frc6378.weebly.com/'}),
#  Team({'address': None, 'city': 'London', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6854', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Thames Valley DSB/North Aircraft/North London Toyota/BOS Innovations/Starlim/Ontario Public Service Employees Union (OPSEU)/London Enconomic Development Corporation/Presitige Car Wash/Real Canadian Superstore/Village Green Family Dentistry&A.B. LUCAS SECONDARY SCHOOL', 'nickname': 'Viking Robotics', 'postal_code': 'N5X 1L8', 'rookie_year': 2018, 'school_name': 'A.B. LUCAS SECONDARY SCHOOL', 'state_prov': 'Ontario', 'team_number': 6854, 'website': 'http://www.frc6854.com/'}),
#  Team({'address': None, 'city': "M'Chigeeng", 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6865', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'McMaster Engineering/Manitoulin Transport/Ontario Power Generation/Argosy/Enbridge Inc./RBC Wealth Management PH&N Investment Counsel/3M/Billings Township/Dairy Farmers of Canada/Henderson Electric Manitoulin/McCann Concrete/JA Rolston Ltd./Island Promotional Products/Pat Noble Lumber/Steele Home Hardware&Manitoulin Secondary School', 'nickname': 'Manitoulin Metal 6865', 'postal_code': 'P0P1G0', 'rookie_year': 2018, 'school_name': 'Manitoulin Secondary School', 'state_prov': 'Ontario', 'team_number': 6865, 'website': 'https://sites.google.com/view/manitoulinmetal/home'}),
#  Team({'address': None, 'city': 'Scarborough', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6975', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Neil McNeil High School', 'nickname': 'Neil McNeil Maroon Machines', 'postal_code': 'M4E 3S2', 'rookie_year': 2018, 'school_name': 'Neil McNeil High School', 'state_prov': 'Ontario', 'team_number': 6975, 'website': None}),
#  Team({'address': None, 'city': 'Saint Catharines', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6978', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Niagara Robotics/Jordan Engineering/Telestream/Vykan Inc./Make It Metal/Woodbridge Foundation/Enbridge Gas/General Motors&Family/Community', 'nickname': 'QuickStrike Niagara', 'postal_code': 'L2S1P4', 'rookie_year': 2018, 'school_name': 'Family/Community', 'state_prov': 'Ontario', 'team_number': 6978, 'website': 'http:///www.niagararobotics.com'}),
#  Team({'address': None, 'city': 'Sarnia', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6992', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Conseil Scolaire Viamonde/Alliance Fabrication Ltd./ FIRST Stewardship Team&École secondaire Franco-Jeunesse', 'nickname': 'FrancoBots', 'postal_code': 'N7S6K2', 'rookie_year': 2018, 'school_name': 'École secondaire Franco-Jeunesse', 'state_prov': 'Ontario', 'team_number': 6992, 'website': None}),
#  Team({'address': None, 'city': 'Cambridge', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7022', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Rockwell Automation/Onsemi&St. Benedicts Catholic Secondary School', 'nickname': 'ACE Robotics', 'postal_code': 'N1R 5W1', 'rookie_year': 2018, 'school_name': 'St. Benedicts Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 7022, 'website': 'https://stbenedict.wcdsb.ca/student-life/clubs/ace-robotics-team/'}),
#  Team({'address': None, 'city': 'Strathroy', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7058', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Parmerit/Armo/The Truck Shop/Hannah Stadler/Strathroy District Collegiate Institute&THAMES VALLEY DISTRICT PUBLIC BOARD', 'nickname': 'StrathDroids', 'postal_code': 'N7G 3H8', 'rookie_year': 2018, 'school_name': 'THAMES VALLEY DISTRICT PUBLIC BOARD', 'state_prov': 'Ontario', 'team_number': 7058, 'website': None}),
#  Team({'address': None, 'city': 'Alliston', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7200', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'FIRST Canada&Banting Memorial High School', 'nickname': 'Banting Memorial high school', 'postal_code': 'L9R 1G5', 'rookie_year': 2018, 'school_name': 'Banting Memorial High School', 'state_prov': 'Ontario', 'team_number': 7200, 'website': None}),
#  Team({'address': None, 'city': 'BRANTFORD', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7509', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Aecon/Six Nations Polytechnic/Rotary Club of Oakville/Putney's Brake and Alignment/Rotary Club of Brantford/McMaster University TA Union (CUPE 3906)/Grand Precision Machining Inc.&Six Nations Polytechnic STEAM Academy", 'nickname': 'Brainstorm Robotics', 'postal_code': 'N3S7P5', 'rookie_year': 2019, 'school_name': 'Six Nations Polytechnic STEAM Academy', 'state_prov': 'Ontario', 'team_number': 7509, 'website': 'https://team7509.ca'}),
#  Team({'address': None, 'city': 'Thornhill', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7520', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'FIRST Canada & Team MineKee & North Toronto Community FIRST Robotics', 'nickname': 'Team MineKee', 'postal_code': 'M2N5B2', 'rookie_year': 2019, 'school_name': 'North Toronto Community FIRST Robotics', 'state_prov': 'Ontario', 'team_number': 7520, 'website': 'http://7520.ca'}),
#  Team({'address': None, 'city': 'Hamilton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7623', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'ArcelorMittal Dofasco/Hamilton-Wentworth Catholic District School Board/FIRST Canada/Johnson Chrysler /KPMG/Runco Law/SHSM /OYAP&St. Thomas More Catholic Secondary School', 'nickname': 'Morebotics', 'postal_code': 'L9B 2N4', 'rookie_year': 2019, 'school_name': 'St. Thomas More Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 7623, 'website': 'https://www.frc7623.com'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7659', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Pratt and Whitney/Hatch/K-Tool/Dassault Systemes/FIRST Canada&Holy Name of Mary College School', 'nickname': 'HNMCS Robotics', 'postal_code': 'L5H2K8', 'rookie_year': 2019, 'school_name': 'Holy Name of Mary College School', 'state_prov': 'Ontario', 'team_number': 7659, 'website': None}),
#  Team({'address': None, 'city': 'Kitchener', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7722', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Rockwell Automation /Sustainability Grant ( Argosy)/Integrated Metal/Erbsville Electric &Resurrection Catholic Secondary School', 'nickname': 'Resurrection MechaPhoenix', 'postal_code': 'N2N 3B9', 'rookie_year': 2019, 'school_name': 'Resurrection Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 7722, 'website': None}),
#  Team({'address': None, 'city': 'Thornhill', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8764', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Thornlea Secondary School/Thornlea Secondary School/Argosy Foundation/Sylvan Learning Center/EMX/and Parents&Thornlea Secondary School', 'nickname': 'Thunder Robotics', 'postal_code': None, 'rookie_year': 2022, 'school_name': 'Thornlea Secondary School', 'state_prov': 'Ontario', 'team_number': 8764, 'website': None}),
#  Team({'address': None, 'city': 'Stratford', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8765', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Nancy Campbell Academy', 'nickname': 'Parallel Units', 'postal_code': None, 'rookie_year': 2022, 'school_name': 'Nancy Campbell Academy', 'state_prov': 'Ontario', 'team_number': 8765, 'website': None}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8884', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Stone's Throw Design Inc./Deloitte Digital /Onyen ESG/PrintPOP/NSS Foundation/NSS School Council/Northern Student Affairs Council/TDSB/Northern Secondary School&Northern Secondary School", 'nickname': 'Knight Owls', 'postal_code': None, 'rookie_year': 2022, 'school_name': 'Northern Secondary School', 'state_prov': 'Ontario', 'team_number': 8884, 'website': None}),
#  Team({'address': None, 'city': 'Hamilton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc9062', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Columbia International College/London North Rotary Club/Thomas Steele/FRC 6336: Javawockies/Argosy Foundation's New Team Grant/FIRST Canada/FRC 5406: Celt-X/NorthPoint Powder Coating/FRC 4039: Makeshift Robotics/Carbon Noir Customs/Family & Friends &Columbia International College", 'nickname': 'Critical Circuits', 'postal_code': None, 'rookie_year': 2023, 'school_name': 'Columbia International College', 'state_prov': 'Ontario', 'team_number': 9062, 'website': None}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc9262', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Humberside Collegiate Institute', 'nickname': 'Humberside Huskies 1', 'postal_code': None, 'rookie_year': 2023, 'school_name': 'Humberside Collegiate Institute', 'state_prov': 'Ontario', 'team_number': 9262, 'website': None})]

# %%
list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        foulb1 = i['score_breakdown']['red']['foulPoints']
        foulb2 = i['score_breakdown']['red']['foulPoints']
        foulb3 = i['score_breakdown']['red']['foulPoints']
        foulr1 = i['score_breakdown']['blue']['foulPoints']
        foulr2 = i['score_breakdown']['blue']['foulPoints']
        foulr3 = i['score_breakdown']['blue']['foulPoints']
        
        dict1 = { teamb1:foulb1
                , teamb2:foulb2
                , teamb3:foulb3
                , teamr1:foulr1
                , teamr2:foulr2
                , teamr3:foulr3}
        list1.append(dict1)
counter = collections.Counter()
for d in list1:
    counter.update(d)

res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=True))

print('Top 3 Foul Points Given')
res
# Out:
# Top 3 Foul Points Given
# {'frc4992': 117,
#  'frc7722': 97,
#  'frc9062': 90,
#  'frc6135': 90,
#  'frc1360': 90,
#  'frc2609': 85,
#  'frc2200': 85,
#  'frc6975': 75,
#  'frc6854': 72,
#  'frc7022': 70,
#  'frc188': 65,
#  'frc7058': 65,
#  'frc7623': 65,
#  'frc6865': 65,
#  'frc8765': 65,
#  'frc6378': 65,
#  'frc4015': 65,
#  'frc1334': 62,
#  'frc9262': 60,
#  'frc8764': 55,
#  'frc5406': 55,
#  'frc1374': 50,
#  'frc6140': 50,
#  'frc1241': 50,
#  'frc6978': 47,
#  'frc6992': 45,
#  'frc7520': 45,
#  'frc7200': 45,
#  'frc2386': 42,
#  'frc4343': 40,
#  'frc1325': 35,
#  'frc1310': 35,
#  'frc7509': 30,
#  'frc7659': 15,
#  'frc8884': 15,
#  'frc2056': 10}

# %%
list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        redbonus = i['score_breakdown']['red']['sustainabilityBonusAchieved']*1
        bluebonus = i['score_breakdown']['blue']['sustainabilityBonusAchieved']*1
        
        dict1 = { teamb1:bluebonus
                , teamb2:bluebonus
                , teamb3:bluebonus
                , teamr1:redbonus
                , teamr2:redbonus
                , teamr3:redbonus}
        list1.append(dict1)
counter = collections.Counter()
for d in list1:
    counter.update(d)

res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=True))

print('3rd Most Sustainability RP')
res
# Out:
# 3rd Most Sustainability RP
# {'frc2056': 12,
#  'frc5406': 7,
#  'frc1325': 7,
#  'frc2609': 6,
#  'frc2200': 6,
#  'frc9062': 4,
#  'frc6865': 4,
#  'frc7659': 4,
#  'frc1310': 4,
#  'frc188': 3,
#  'frc7058': 3,
#  'frc4343': 3,
#  'frc1334': 3,
#  'frc8765': 3,
#  'frc4015': 3,
#  'frc1241': 3,
#  'frc8764': 2,
#  'frc7623': 2,
#  'frc7509': 2,
#  'frc4992': 2,
#  'frc2386': 2,
#  'frc7200': 2,
#  'frc6978': 1,
#  'frc6975': 1,
#  'frc6135': 1,
#  'frc6140': 1,
#  'frc6378': 1,
#  'frc6854': 1,
#  'frc7722': 1,
#  'frc6992': 1,
#  'frc7520': 1,
#  'frc8884': 1,
#  'frc7022': 1,
#  'frc1360': 1,
#  'frc9262': 0,
#  'frc1374': 0}

# %%
# list1 = []
# for i in tba.event_matches(event):
#     if i['comp_level'] == 'qm':
#         teamb1 = i['alliances']['blue']['team_keys'][0]
#         teamb2 = i['alliances']['blue']['team_keys'][1]
#         teamb3 = i['alliances']['blue']['team_keys'][2]
#         teamr1 = i['alliances']['red']['team_keys'][0]
#         teamr2 = i['alliances']['red']['team_keys'][1]
#         teamr3 = i['alliances']['red']['team_keys'][2]
        
#         redbonus = i['score_breakdown']['red']['coopertitionCriteriaMet']*1
#         bluebonus = i['score_breakdown']['blue']['coopertitionCriteriaMet']*1
        
#         dict1 = { teamb1:bluebonus
#                 , teamb2:bluebonus
#                 , teamb3:bluebonus
#                 , teamr1:redbonus
#                 , teamr2:redbonus
#                 , teamr3:redbonus}
#         list1.append(dict1)
# counter = collections.Counter()
# for d in list1:
#     counter.update(d)

# res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=False))

# print('Most Selfish Team (least co-op points)')
# res

# %%
def endgame_pts(value):
    if value == 'Docked': return 1
    else: return 0

list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        endb1 = endgame_pts(i['score_breakdown']['blue']['autoChargeStationRobot1']) - endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot1'])
        endb2 = endgame_pts(i['score_breakdown']['blue']['autoChargeStationRobot2']) - endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot2'])
        endb3 = endgame_pts(i['score_breakdown']['blue']['autoChargeStationRobot3']) - endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot3'])
        endr1 = endgame_pts(i['score_breakdown']['red']['autoChargeStationRobot1']) - endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot1'])
        endr2 = endgame_pts(i['score_breakdown']['red']['autoChargeStationRobot2']) - endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot2'])
        endr3 = endgame_pts(i['score_breakdown']['red']['autoChargeStationRobot3']) - endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot3'])
        
        dict1 = { teamb1:endb1
                , teamb2:endb2
                , teamb3:endb3
                , teamr1:endr1
                , teamr2:endr2
                , teamr3:endr3}
        list1.append(dict1)

counter = collections.Counter()
for d in list1:
    counter.update(d)
    
res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=True))

print('More Auto Docks than End Game Docks')
res
# Out:
# More Auto Docks than End Game Docks
# {'frc2609': 5,
#  'frc2056': 3,
#  'frc1325': 1,
#  'frc5406': 0,
#  'frc6978': -1,
#  'frc188': -2,
#  'frc4992': -2,
#  'frc2200': -2,
#  'frc4015': -3,
#  'frc2386': -3,
#  'frc1241': -3,
#  'frc1310': -3,
#  'frc6865': -4,
#  'frc6140': -4,
#  'frc8765': -4,
#  'frc7722': -4,
#  'frc6135': -5,
#  'frc9262': -6,
#  'frc6975': -6,
#  'frc7058': -6,
#  'frc6378': -6,
#  'frc9062': -7,
#  'frc8764': -7,
#  'frc1374': -7,
#  'frc7623': -7,
#  'frc6992': -7,
#  'frc7520': -7,
#  'frc7659': -7,
#  'frc4343': -8,
#  'frc6854': -8,
#  'frc7022': -8,
#  'frc1360': -8,
#  'frc7200': -8,
#  'frc1334': -9,
#  'frc8884': -9,
#  'frc7509': -10}

# %%
def endgame_pts(value):
    if value == 'Docked': return 1
    elif value == 'NotLevel': return 1
    else: return 0

list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        endb1 = endgame_pts(i['score_breakdown']['blue']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot1'])
        endb2 = endgame_pts(i['score_breakdown']['blue']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot2'])
        endb3 = endgame_pts(i['score_breakdown']['blue']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot3'])
        endr1 = endgame_pts(i['score_breakdown']['red']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot1'])
        endr2 = endgame_pts(i['score_breakdown']['red']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot2'])
        endr3 = endgame_pts(i['score_breakdown']['red']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot3'])
        
        dict1 = { teamb1:endb1
                , teamb2:endb2
                , teamb3:endb3
                , teamr1:endr1
                , teamr2:endr2
                , teamr3:endr3}
        list1.append(dict1)

counter = collections.Counter()
for d in list1:
    counter.update(d)
    
res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=True))

print('Added Most End Game Docks without Engages')
res
# Out:
# Added Most End Game Docks without Engages
# {'frc6978': 4,
#  'frc9262': 2,
#  'frc188': 2,
#  'frc7058': 2,
#  'frc5406': 2,
#  'frc2056': 2,
#  'frc2200': 2,
#  'frc9062': 1,
#  'frc1374': 1,
#  'frc7623': 1,
#  'frc1325': 1,
#  'frc7509': 1,
#  'frc7722': 1,
#  'frc4015': 1,
#  'frc7520': 1,
#  'frc1241': 1,
#  'frc6975': 0,
#  'frc8764': 0,
#  'frc4343': 0,
#  'frc6135': 0,
#  'frc6865': 0,
#  'frc6140': 0,
#  'frc1334': 0,
#  'frc8765': 0,
#  'frc6378': 0,
#  'frc4992': 0,
#  'frc6854': 0,
#  'frc6992': 0,
#  'frc2609': 0,
#  'frc2386': 0,
#  'frc7659': 0,
#  'frc8884': 0,
#  'frc7022': 0,
#  'frc1310': 0,
#  'frc1360': 0,
#  'frc7200': 0}

# %%
def endgame_pts(value):
    if value == 'Docked': return 1
    elif value == 'Level': return 1
    else: return 0

list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        endb1 = endgame_pts(i['score_breakdown']['blue']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot1'])
        endb2 = endgame_pts(i['score_breakdown']['blue']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot2'])
        endb3 = endgame_pts(i['score_breakdown']['blue']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['blue']['endGameChargeStationRobot3'])
        endr1 = endgame_pts(i['score_breakdown']['red']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot1'])
        endr2 = endgame_pts(i['score_breakdown']['red']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot2'])
        endr3 = endgame_pts(i['score_breakdown']['red']['endGameBridgeState']) * endgame_pts(i['score_breakdown']['red']['endGameChargeStationRobot3'])
        
        dict1 = { teamb1:endb1
                , teamb2:endb2
                , teamb3:endb3
                , teamr1:endr1
                , teamr2:endr2
                , teamr3:endr3}
        list1.append(dict1)

counter = collections.Counter()
for d in list1:
    counter.update(d)
    
res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=False))

print('Least Teleop Engaged (Team)')
res
# Out:
# Least Teleop Engaged (Team)
# {'frc4015': 2,
#  'frc1325': 3,
#  'frc9262': 4,
#  'frc5406': 4,
#  'frc6140': 4,
#  'frc8765': 4,
#  'frc188': 5,
#  'frc6865': 5,
#  'frc2056': 5,
#  'frc6975': 6,
#  'frc9062': 6,
#  'frc7623': 6,
#  'frc6378': 6,
#  'frc7722': 6,
#  'frc7520': 6,
#  'frc2386': 6,
#  'frc1241': 6,
#  'frc6978': 7,
#  'frc8764': 7,
#  'frc6135': 7,
#  'frc6992': 7,
#  'frc2609': 7,
#  'frc7659': 7,
#  'frc2200': 7,
#  'frc4343': 8,
#  'frc6854': 8,
#  'frc1360': 8,
#  'frc7200': 8,
#  'frc7058': 9,
#  'frc7509': 9,
#  'frc1334': 9,
#  'frc7022': 9,
#  'frc1374': 10,
#  'frc4992': 10,
#  'frc8884': 10,
#  'frc1310': 11}

# %%
list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        autoblueVal = i['score_breakdown']['blue']['teleopCommunity']['M']
        autoblueCount = len(autoblueVal) - autoblueVal.count('None')

        autoredVal = i['score_breakdown']['red']['teleopCommunity']['M']
        autoredCount = len(autoredVal) - autoredVal.count('None')
        
        dict1 = { teamb1:autoblueCount
                , teamb2:autoblueCount
                , teamb3:autoblueCount
                , teamr1:autoredCount
                , teamr2:autoredCount
                , teamr3:autoredCount}
        list1.append(dict1)
counter = collections.Counter()
for d in list1:
    counter.update(d)

res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=True))

print('Most Mid Team')
res
# Out:
# Most Mid Team
# {'frc2056': 75,
#  'frc2200': 70,
#  'frc6978': 68,
#  'frc1325': 48,
#  'frc8884': 48,
#  'frc1374': 44,
#  'frc6992': 41,
#  'frc2609': 40,
#  'frc7520': 39,
#  'frc7200': 38,
#  'frc7659': 35,
#  'frc1241': 35,
#  'frc7623': 34,
#  'frc2386': 33,
#  'frc1310': 33,
#  'frc7022': 32,
#  'frc7058': 31,
#  'frc7509': 31,
#  'frc6975': 30,
#  'frc4992': 30,
#  'frc1360': 29,
#  'frc188': 27,
#  'frc8764': 26,
#  'frc4343': 25,
#  'frc6865': 25,
#  'frc6378': 25,
#  'frc4015': 25,
#  'frc6140': 24,
#  'frc1334': 24,
#  'frc7722': 24,
#  'frc9062': 21,
#  'frc8765': 21,
#  'frc6854': 21,
#  'frc5406': 19,
#  'frc9262': 14,
#  'frc6135': 12}

# %%
list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        autoblueVal = 0
        autoredVal = 0
        
        for j in i['score_breakdown']['blue']['teleopCommunity'].values():
            autoblueVal += j.count('Cone')
            autoblueVal -= j.count('Cube')

        for j in i['score_breakdown']['red']['teleopCommunity'].values():
            autoredVal += j.count('Cone')
            autoredVal -= j.count('Cube')
        
        dict1 = { teamb1:autoblueVal
                , teamb2:autoblueVal
                , teamb3:autoblueVal
                , teamr1:autoredVal
                , teamr2:autoredVal
                , teamr3:autoredVal}
        list1.append(dict1)
counter = collections.Counter()
for d in list1:
    counter.update(d)

res = dict(sorted(counter.items(), key=lambda item: abs(item[1]), reverse=True))

print('Biggest difference between Cones vs Cubes')
res
# Out:
# Biggest difference between Cones vs Cubes
# {'frc2056': 63,
#  'frc7058': -61,
#  'frc9062': -47,
#  'frc4992': -41,
#  'frc2386': 38,
#  'frc188': -36,
#  'frc7200': -36,
#  'frc6992': -33,
#  'frc6854': -32,
#  'frc1334': -31,
#  'frc1241': 28,
#  'frc1310': 27,
#  'frc9262': -25,
#  'frc7722': -22,
#  'frc7520': -22,
#  'frc7509': -20,
#  'frc8884': 20,
#  'frc6865': -19,
#  'frc8765': -19,
#  'frc7623': -18,
#  'frc1325': 18,
#  'frc7022': -17,
#  'frc4015': -15,
#  'frc6975': -12,
#  'frc6978': 11,
#  'frc4343': 9,
#  'frc5406': -9,
#  'frc6378': -8,
#  'frc2609': 8,
#  'frc7659': -7,
#  'frc6140': 6,
#  'frc1360': 6,
#  'frc2200': 5,
#  'frc1374': -2,
#  'frc8764': 1,
#  'frc6135': 1}

# %%
# dict1 = tba.event_oprs(event)['oprs']

# list1 = []
# for i in tba.event_matches(event):
#     if i['comp_level'] == 'qm':
#         teamb1 = i['alliances']['blue']['team_keys'][0]
#         teamb2 = i['alliances']['blue']['team_keys'][1]
#         teamb3 = i['alliances']['blue']['team_keys'][2]
#         teamr1 = i['alliances']['red']['team_keys'][0]
#         teamr2 = i['alliances']['red']['team_keys'][1]
#         teamr3 = i['alliances']['red']['team_keys'][2]

#         val = dict1[teamb1] + dict1[teamb2] + dict1[teamb3] - dict1[teamr1] - dict1[teamr2] - dict1[teamr3]
        
    
#         if i['winning_alliance'] == 'red':
#             val = -val
        
#         dict2 = {i['match_number']:val}
#         list1.append(dict2)
# counter = collections.Counter()
# for d in list1:
#     counter.update(d)

# res = sorted(counter.items(), key=lambda item: item[1], reverse=False)

# # print(res)
# print('Winners & Losers of Biggest Upset')


# for i in tba.event_matches(event):
#     if i['comp_level'] == 'qm' and i['match_number'] == res[0][0]:
#         print(i['alliances']['red']['team_keys'], i['alliances']['blue']['team_keys'])

# %%
list1 = []
for i in tba.event_matches(event):
    if i['comp_level'] == 'qm':
        teamb1 = i['alliances']['blue']['team_keys'][0]
        teamb2 = i['alliances']['blue']['team_keys'][1]
        teamb3 = i['alliances']['blue']['team_keys'][2]
        teamr1 = i['alliances']['red']['team_keys'][0]
        teamr2 = i['alliances']['red']['team_keys'][1]
        teamr3 = i['alliances']['red']['team_keys'][2]
        
        autoblueVal = 0
        autoredVal = 0
        
        for j in i['score_breakdown']['blue']['autoCommunity'].values():
            autoblueVal += len(j)
            autoblueVal -= j.count('None')
            
        for j in i['score_breakdown']['red']['autoCommunity'].values():
            autoredVal += len(j)
            autoredVal -= j.count('None')
        
        dict1 = { teamb1:autoblueVal
                , teamb2:autoblueVal
                , teamb3:autoblueVal
                , teamr1:autoredVal
                , teamr2:autoredVal
                , teamr3:autoredVal}
        list1.append(dict1)
counter = collections.Counter()
for d in list1:
    counter.update(d)

res = dict(sorted(counter.items(), key=lambda item: item[1], reverse=True))

print('Top 3 teams in auto game pieces scored')
res
# Out:
# Top 3 teams in auto game pieces scored
# {'frc2056': 52,
#  'frc2200': 42,
#  'frc1325': 38,
#  'frc4992': 36,
#  'frc1241': 35,
#  'frc1310': 35,
#  'frc7509': 33,
#  'frc2609': 33,
#  'frc6978': 32,
#  'frc7058': 32,
#  'frc6378': 32,
#  'frc6992': 32,
#  'frc8884': 32,
#  'frc6854': 31,
#  'frc7520': 31,
#  'frc8764': 30,
#  'frc4343': 30,
#  'frc6135': 30,
#  'frc7722': 30,
#  'frc7659': 30,
#  'frc188': 29,
#  'frc1374': 29,
#  'frc5406': 29,
#  'frc7022': 29,
#  'frc7200': 29,
#  'frc2386': 28,
#  'frc6865': 27,
#  'frc8765': 27,
#  'frc1360': 26,
#  'frc6140': 25,
#  'frc9062': 24,
#  'frc6975': 23,
#  'frc7623': 22,
#  'frc1334': 22,
#  'frc9262': 21,
#  'frc4015': 20}

# %%
# list1 = []
# for i in tba.event_matches(event):
#     if i['comp_level'] == 'qm':
#         teamb1 = i['alliances']['blue']['team_keys'][0]
#         teamb2 = i['alliances']['blue']['team_keys'][1]
#         teamb3 = i['alliances']['blue']['team_keys'][2]
#         teamr1 = i['alliances']['red']['team_keys'][0]
#         teamr2 = i['alliances']['red']['team_keys'][1]
#         teamr3 = i['alliances']['red']['team_keys'][2]
        
#         score = i['alliances']['blue']['score'] + i['alliances']['red']['score']
        
#         dict1 = { i['match_number']:score}
#         list1.append(dict1)
# counter = collections.Counter()
# for d in list1:
#     counter.update(d)

# res = sorted(counter.items(), key=lambda item: item[1], reverse=True)

# print('Losers in Highest Scored Match')
# print(res[0][0])
# for i in tba.event_matches(event):
#     if i['comp_level'] == 'qm' and i['match_number'] == res[0][0]:
#         if i['winning_alliance'] == 'blue':
#             print(i['alliances']['red']['team_keys'])
#         else:
#             print(i['alliances']['blue']['team_keys'])

# %%
# print('Losers in Highest Scored Match')
# for i in tba.event_matches(event):
#     if i['key'] == tba.event_insights(event)['qual']['high_score'][1]:
#         if i['winning_alliance'] == 'blue':
#             print(i['alliances']['red']['team_keys'])
#         else:
#             print(i['alliances']['blue']['team_keys'])

# %%
# print('Quals High Score')
# tba.event_insights(event)['qual']['high_score']

# %%
print('Last 3 Picks')
print(tba.event_alliances(event)[0]['picks'][2])
print(tba.event_alliances(event)[1]['picks'][2])
print(tba.event_alliances(event)[2]['picks'][2])
# Out:
# Last 3 Picks
# frc4992
# frc6854
# frc7722

# %%
print('3rd Alliance Captain')
print(tba.event_alliances(event)[2]['picks'][0])
# Out:
# 3rd Alliance Captain
# frc5406

# %%
dict1 = {}
for r in tba.event_rankings(event)['rankings']:
    team_key = r['team_key']
    dict1[team_key] = r['rank']
    
dict2 = {}
for key, value in tba.event_district_points(event)['points'].items():
    if value['alliance_points'] == 0:
        dict2[key] = dict1[key]

print('Top 5 Left out of Elims')
print(sorted(dict2.items(), key=lambda x:x[1]))
# Out:
# Top 5 Left out of Elims
# [('frc6865', 18), ('frc1334', 20), ('frc7659', 22), ('frc8764', 25), ('frc9062', 26), ('frc7520', 27), ('frc6992', 28), ('frc6975', 29), ('frc7623', 30), ('frc6135', 32), ('frc4015', 33), ('frc9262', 36)]

# %%
dict1 = {}
for r in tba.event_rankings(event)['rankings']:
    team_key = r['team_key']
    dict1[team_key] = r['rank']
dict1
# Out:
# {'frc2056': 1,
#  'frc1325': 2,
#  'frc2609': 3,
#  'frc5406': 4,
#  'frc1241': 5,
#  'frc8884': 6,
#  'frc2200': 7,
#  'frc1310': 8,
#  'frc7058': 9,
#  'frc6978': 10,
#  'frc4343': 11,
#  'frc7509': 12,
#  'frc6378': 13,
#  'frc1374': 14,
#  'frc1360': 15,
#  'frc7022': 16,
#  'frc7200': 17,
#  'frc6865': 18,
#  'frc2386': 19,
#  'frc1334': 20,
#  'frc4992': 21,
#  'frc7659': 22,
#  'frc8765': 23,
#  'frc6140': 24,
#  'frc8764': 25,
#  'frc9062': 26,
#  'frc7520': 27,
#  'frc6992': 28,
#  'frc6975': 29,
#  'frc7623': 30,
#  'frc6854': 31,
#  'frc6135': 32,
#  'frc4015': 33,
#  'frc7722': 34,
#  'frc188': 35,
#  'frc9262': 36}

# %%
tba.event_teams(event)
# Out:
# [Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1241', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'General Motors/Pratt & Whitney Canada/Johnston Industrial Plastics Limited/CSC/Zerox/DBG Canada Limited/Symcor/Rev Creations/Rakla Tires/Click N Print/Trans Canada/99Cent Depot/Dreams Convention Center/Studica/City of Mississauga/Peel District School Board&Rick Hansen S.S', 'nickname': 'THEORY6', 'postal_code': 'L5V 1N6', 'rookie_year': 2004, 'school_name': 'Rick Hansen S.S', 'state_prov': 'Ontario', 'team_number': 1241, 'website': 'http://www.theory6.ca'}),
#  Team({'address': None, 'city': 'North Bay', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1305', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Canadore College/Nipissing University/PEO North Bay Chapter/Near North District School Board/General Motors/Enbridge Gas&Near North Student Robotics Initiative', 'nickname': 'Ice Cubed', 'postal_code': 'P1B 8K5', 'rookie_year': 2004, 'school_name': 'Near North Student Robotics Initiative', 'state_prov': 'Ontario', 'team_number': 1305, 'website': 'http://www.team1305.org'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1360', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Gyptech/TC Energy/Studica/Ford Motor Company/Desjardins Foundation/Pratt & Whitney Canada/Rockwell Automation/Magna/Woodbridge Foam Corporation/Town of Oakville/Oakville Community Foundation&Oakville Community FIRST Robotics', 'nickname': 'Orbit Robotics', 'postal_code': 'L6J 3H1', 'rookie_year': 2004, 'school_name': 'Oakville Community FIRST Robotics', 'state_prov': 'Ontario', 'team_number': 1360, 'website': 'https://www.1360.ca'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc1374', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Halton District School Board - Technological Education (HDSB TE)/Hatch/Sinn Development&OAKVILLE TRAFALGAR HIGH SCHOOL', 'nickname': 'Amped Up', 'postal_code': 'l6j 3l6', 'rookie_year': 2004, 'school_name': 'OAKVILLE TRAFALGAR HIGH SCHOOL', 'state_prov': 'Ontario', 'team_number': 1374, 'website': 'http://www.1374.ca'}),
#  Team({'address': None, 'city': 'Stoney Creek', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2056', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'ArcelorMittal Dofasco/GM/HWDSB&Orchard Park Secondary School', 'nickname': 'OP Robotics', 'postal_code': 'L8E 4M5', 'rookie_year': 2007, 'school_name': 'Orchard Park Secondary School', 'state_prov': 'Ontario', 'team_number': 2056, 'website': 'http://www.2056.ca'}),
#  Team({'address': None, 'city': 'Burlington', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2200', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Arcelor Mittal Dofasco Hamilton/Almex Group/Shape Process Automation/Wera Tools/Pratt and Whitney Canada/Burlington Auto Works/Custom Paint & Silk Screen Inc./Studica Canada/Full Fusion Welding/Pacsys /Advent Tech /Irving Consumer&M.M. Robinson High School', 'nickname': 'MMRambotics', 'postal_code': 'L7P 3N9', 'rookie_year': 2007, 'school_name': 'M.M. Robinson High School', 'state_prov': 'Ontario', 'team_number': 2200, 'website': 'http://www.mmrambotics.com'}),
#  Team({'address': None, 'city': 'North York', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2634', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Pratt and Whitney Canada/Computer Sciences Corp&Chaminade College', 'nickname': 'The Gryphons', 'postal_code': 'M6L 1M8', 'rookie_year': 2008, 'school_name': 'Chaminade College', 'state_prov': 'Ontario', 'team_number': 2634, 'website': 'http://www.team2634.com'}),
#  Team({'address': None, 'city': 'Waterloo', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2702', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Google/Region of Waterloo/Novatek Welding & Fabrication&Kitchener Waterloo Youth Robotics', 'nickname': 'Rebels', 'postal_code': 'N2H 1H6', 'rookie_year': 2009, 'school_name': 'Kitchener Waterloo Youth Robotics', 'state_prov': 'Ontario', 'team_number': 2702, 'website': 'http://www.2702rebels.com/'}),
#  Team({'address': None, 'city': 'St Catharines', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc2852', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'General Motors/Ward Industrial Equipment Inc./FABRIS/Vykan Manufacturing/Ontario Power Generation/Multiplex Manufacturing/Niagara Catholic District School Board&Denis Morris Catholic High School', 'nickname': 'DM High Voltage', 'postal_code': 'L2T 2M9', 'rookie_year': 2009, 'school_name': 'Denis Morris Catholic High School', 'state_prov': 'Ontario', 'team_number': 2852, 'website': 'http://2852.ca/'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc3161', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Halton Catholic District School Board/Professional Engineers Ontario Oakville Chapter/Creative Visual Solutions&Holy Trinity Catholic Secondary', 'nickname': 'Tronic Titans', 'postal_code': 'L6H 5Z8', 'rookie_year': 2010, 'school_name': 'Holy Trinity Catholic Secondary', 'state_prov': 'Ontario', 'team_number': 3161, 'website': 'http://www.team3161.ca/'}),
#  Team({'address': None, 'city': 'Waterloo', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc3683', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Quantum Valley Investments/Melitron/Benmur/ATS Automation&St. David Catholic Secondary School', 'nickname': 'Team DAVE', 'postal_code': 'N2L 3X5', 'rookie_year': 2011, 'school_name': 'St. David Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 3683, 'website': 'http://www.teamdave.ca'}),
#  Team({'address': None, 'city': 'Huntsville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4152', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Marwood International/Kimberly-Clark/Seals For Life/Rotary Club of Huntsville&Huntsville High School', 'nickname': 'Hoya Robotics', 'postal_code': 'P1H 2A2', 'rookie_year': 2012, 'school_name': 'Huntsville High School', 'state_prov': 'Ontario', 'team_number': 4152, 'website': 'https://hoyarobotics.wixsite.com/team4152-hoya'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4308', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Weston Forest/Mississauga Central Lions Club/Sable Metal/Bramwood Forest Inc/Jukebox&The Woodlands School', 'nickname': 'ABSOLUTE ROBOTICS', 'postal_code': 'L5C1Y5', 'rookie_year': 2012, 'school_name': 'The Woodlands School', 'state_prov': 'Ontario', 'team_number': 4308, 'website': 'http://team4308.ca/'}),
#  Team({'address': None, 'city': 'Kingston', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4476', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Kingston Community Health Centres/Novelis/Pure Ingenuity/Ontario Power Generation/Queen's University/Studica/Fab-Cut Systems/Spectrum Education/Our Families&W.A.F.F.L.E.S. Community Robotics", 'nickname': 'W.A.F.F.L.E.S.', 'postal_code': 'K7L 4V4', 'rookie_year': 2013, 'school_name': 'W.A.F.F.L.E.S. Community Robotics', 'state_prov': 'Ontario', 'team_number': 4476, 'website': 'http://wafflesrobotics.com/'}),
#  Team({'address': None, 'city': 'King', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4951', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'The Country Day School', 'nickname': 'CDS Cyclones', 'postal_code': 'L7B1K5', 'rookie_year': 2014, 'school_name': 'The Country Day School', 'state_prov': 'Ontario', 'team_number': 4951, 'website': 'http://www.firstinspires.org/'}),
#  Team({'address': None, 'city': 'Georgetown', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4976', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Flodraulic/GE Healthcare/Hey Ray Real Estate/Georgetown Rotary Club/Canadian Tire&Georgetown District High School', 'nickname': 'Revolt Robotics', 'postal_code': 'L7G3Z5', 'rookie_year': 2014, 'school_name': 'Georgetown District High School', 'state_prov': 'Ontario', 'team_number': 4976, 'website': 'https://www.team4976.com'}),
#  Team({'address': None, 'city': 'Milton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc4992', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Halton District School Board Technical Education, Pathways and SHSM/Craig Kielburger Secondary School Hospitality&Craig Kielburger Secondary School', 'nickname': 'Sparbotics', 'postal_code': 'L9T 7V8', 'rookie_year': 2014, 'school_name': 'Craig Kielburger Secondary School', 'state_prov': 'Ontario', 'team_number': 4992, 'website': 'http://www.4992.ca'}),
#  Team({'address': None, 'city': 'North York', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5031', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Toronto District School Board/3M/RBC/GM/Dr. Tom Lee / Richard Lee&Downsview secondary', 'nickname': 'Full Metal Mustangs', 'postal_code': 'M3K 1W3', 'rookie_year': 2014, 'school_name': 'Downsview secondary', 'state_prov': 'Ontario', 'team_number': 5031, 'website': 'http:///www.downsviewrobotics.weebly.com'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5032', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Advanced Motion and Controls/Conovey/THK Canada/Nye Manufacturing/Lakeside Process Controls/TE Connectivity/Gene Haas Foundation/Siemens Energy/Weston Forest/Moddules/No Frills Dennis/GM/Siemens Canada&Meadowvale Secondary School', 'nickname': 'Falcons', 'postal_code': 'L5N3B2', 'rookie_year': 2014, 'school_name': 'Meadowvale Secondary School', 'state_prov': 'Ontario', 'team_number': 5032, 'website': 'http://www.firstinspires.org/'}),
#  Team({'address': None, 'city': 'Hamilton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5406', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'HWCDSB/John Deere Canada/HATCH/Arcelor-Mittal Dofasco/Jantz Canada/Rev Robotics&Bishop Ryan Catholic Secondary School', 'nickname': 'Celt-X', 'postal_code': 'L0R1P0', 'rookie_year': 2015, 'school_name': 'Bishop Ryan Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 5406, 'website': 'https://5406.ca'}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5409', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Halton District School Board/BMP Metals/ABC Technologies/Samuel Steel/Taylor Steel/IUOE (Local 793)/HATCH Canada&Garth Webb Secondary School', 'nickname': 'Chargers', 'postal_code': 'L6M 4W2', 'rookie_year': 2015, 'school_name': 'Garth Webb Secondary School', 'state_prov': 'Ontario', 'team_number': 5409, 'website': 'https://www.garthwebbrobotics.ca'}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5719', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'FIRST Robotics Canada/RBC Wealth Management PH&N Investment Counsel/Kiwanis Club of Casa Loma/Toronto District School Board&David & Mary Thomson Collegiate Institute', 'nickname': 'Pink Titans', 'postal_code': 'M1P2S7', 'rookie_year': 2015, 'school_name': 'David & Mary Thomson Collegiate Institute', 'state_prov': 'Ontario', 'team_number': 5719, 'website': 'http://www.PinkTitans.ca'}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc5834', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Riverdale Collegiate Institute/Optimist Club of Etobicoke/Metropolitan University-DMZ/Thinking Cap/Charlie's Meat and Seafood/Home Depot&Riverdale Collegiate Institute", 'nickname': 'R3P2', 'postal_code': 'M4M 2A1', 'rookie_year': 2016, 'school_name': 'Riverdale Collegiate Institute', 'state_prov': 'Ontario', 'team_number': 5834, 'website': 'http://riverdalerobotics.com/'}),
#  Team({'address': None, 'city': 'Scarborough', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6140', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Microsoft Corporation/RBC Wealth Management PH & N Group/Enbridge Gas Team Sponsorship Grant/Argosy Hardship Grant/TORONTO CATHOLIC DISTRICT SCHOOL BOARD - 21st Century Learning&St. Mother Teresa Catholic Academy', 'nickname': "SMT Titans - The 'Tita'BOTS", 'postal_code': 'M1B 3G5', 'rookie_year': 2016, 'school_name': 'St. Mother Teresa Catholic Academy', 'state_prov': 'Ontario', 'team_number': 6140, 'website': 'http://www.twitter.com/smtrobotics'}),
#  Team({'address': None, 'city': 'Saint Catharines', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc6978', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Niagara Robotics/Jordan Engineering/Telestream/Vykan Inc./Make It Metal/Woodbridge Foundation/Enbridge Gas/General Motors&Family/Community', 'nickname': 'QuickStrike Niagara', 'postal_code': 'L2S1P4', 'rookie_year': 2018, 'school_name': 'Family/Community', 'state_prov': 'Ontario', 'team_number': 6978, 'website': 'http:///www.niagararobotics.com'}),
#  Team({'address': None, 'city': 'Cambridge', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7022', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Rockwell Automation/Onsemi&St. Benedicts Catholic Secondary School', 'nickname': 'ACE Robotics', 'postal_code': 'N1R 5W1', 'rookie_year': 2018, 'school_name': 'St. Benedicts Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 7022, 'website': 'https://stbenedict.wcdsb.ca/student-life/clubs/ace-robotics-team/'}),
#  Team({'address': None, 'city': 'Etobicoke', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7136', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Urban Digital Solutions/Mera Window Fasions/Six Brothers Stables/Waterloo Electro-Plating/Toronto District School Board&Thistletown Collegiate Institute', 'nickname': 'Thistletown Scot Bots', 'postal_code': 'M9W 2T4', 'rookie_year': 2018, 'school_name': 'Thistletown Collegiate Institute', 'state_prov': 'Ontario', 'team_number': 7136, 'website': None}),
#  Team({'address': None, 'city': 'Kingston', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7480', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': '2019 Argosy Foundation FRC Rookie Grant/Novelis Inc./FIRST Canada/Retired Teachers of Ontario/Electro-meters/iStorm/QFRC/Server Cloud&Family/Community', 'nickname': 'Machine Mavericks', 'postal_code': 'K7L2Z5', 'rookie_year': 2019, 'school_name': 'Family/Community', 'state_prov': 'Ontario', 'team_number': 7480, 'website': 'https://www.machinemavericks.com/'}),
#  Team({'address': None, 'city': 'North York', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7558', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Bayview Glen School/Bot Camp/Caution Tape Robotics/Lenovo&BAYVIEW GLEN SCHOOL', 'nickname': 'ALT-F4', 'postal_code': 'M3B 3H9', 'rookie_year': 2019, 'school_name': 'BAYVIEW GLEN SCHOOL', 'state_prov': 'Ontario', 'team_number': 7558, 'website': 'https://www.team7558.com'}),
#  Team({'address': None, 'city': 'Mississauga', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7659', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Pratt and Whitney/Hatch/K-Tool/Dassault Systemes/FIRST Canada&Holy Name of Mary College School', 'nickname': 'HNMCS Robotics', 'postal_code': 'L5H2K8', 'rookie_year': 2019, 'school_name': 'Holy Name of Mary College School', 'state_prov': 'Ontario', 'team_number': 7659, 'website': None}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc771', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Collins Aerospace Systems/Hatch/Shaw Almex&St. Mildred's Lightbourn School", 'nickname': 'SWAT', 'postal_code': 'L6J 2L1', 'rookie_year': 2002, 'school_name': "St. Mildred's Lightbourn School", 'state_prov': 'Ontario', 'team_number': 771, 'website': 'http://www.swat771.com'}),
#  Team({'address': None, 'city': 'Scarborough', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc7712', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'ACCN/FIRST/Lassonde School of Engineering and York University&African Canadian Christian Network', 'nickname': 'ACCN UMOJA', 'postal_code': 'M1L0H2', 'rookie_year': 2019, 'school_name': 'African Canadian Christian Network', 'state_prov': 'Ontario', 'team_number': 7712, 'website': None}),
#  Team({'address': None, 'city': 'LaSalle', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc772', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'General Motors of Canada/Centerline Windsor Ltd./SWT Group/St Clair College/University of Windsor/Tregaskiss/SMSH - Special High Skills Major/Novelletto /LaSalle Police Youth Foundation/Malden Dental /Seven Lakes Championship Golf&Sandwich Secondary School', 'nickname': 'Sabre Bytes Robotics', 'postal_code': 'N9J 2T5', 'rookie_year': 2002, 'school_name': 'Sandwich Secondary School', 'state_prov': 'Ontario', 'team_number': 772, 'website': 'http://www.sabrerobotics.com'}),
#  Team({'address': None, 'city': 'Kincardine', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc781', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Bruce Power/Kinetic Knights Youth Robotics&Family/Community', 'nickname': 'Kinetic Knights', 'postal_code': 'N2Z 2B9', 'rookie_year': 2002, 'school_name': 'Family/Community', 'state_prov': 'Ontario', 'team_number': 781, 'website': 'http://www.kineticknights.org irŕ'}),
#  Team({'address': None, 'city': 'Leamington', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8081', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Uni-fab/Caxton Mark/Nature Fresh Farms/Great Lakes Greenhouses/PrimeVine Produce/Speedy Glass/UE Enclosures/Bartel Machine and Welding/University of Windsor - Faculty of Science/St. Clair College/Schartner Construction/LSI Supply Inc/Electric Wholesale Supply/Fittler Farms/Setterington’s Fertilizer/Wilkinson Electric/Home Hardware/Warkentin Tree Farm/Panther Manufacturing/Economy Rental Centre/Banwell Douglas/MC3/D& T Auto Parts CarQuest/Centerline/Agris coop/WFS /My Ride/C & R Renwick Seeds/Ray Jaarsma/Kal Tire/Speedprint/Lycoland Farms/Tec-Land Farms/Clover View Farms/Dueck Citizenship and Immigration/Delta Power/Huron Tractor/Oliveira Equipment/Yurkes Sales and Equipment/Steele Electric Supply/Ridder Innovative Technical Solutions/Chosen Fresh Farms/Langeman Mfg/KJM Manufacturing&UMEI', 'nickname': 'UMEI Lightning Robotics', 'postal_code': 'N8H 3V8', 'rookie_year': 2020, 'school_name': 'UMEI', 'state_prov': 'Ontario', 'team_number': 8081, 'website': 'https://umeilightningrobot.wixsite.com/christianhighschool'}),
#  Team({'address': None, 'city': 'Kitchener', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8089', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'Vigor Clean Tech/Keeping It Simple/Engenuity Corporation/Northern Digital Inc. /Rockway Mennonite Collegiate&Rockway Mennonite Collegiate', 'nickname': 'Rockway Robotics', 'postal_code': 'N2G 3C8', 'rookie_year': 2020, 'school_name': 'Rockway Mennonite Collegiate', 'state_prov': 'Ontario', 'team_number': 8089, 'website': None}),
#  Team({'address': None, 'city': 'Newmarket', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8349', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'FIRST Canada Rookie Grant/New Team Growth Grant/NewMakeIt/Tech-Pre/Magna International/SicoSoft Consulting&Newbotics Community Robotics', 'nickname': 'Newbotics', 'postal_code': 'L3Y 1R9', 'rookie_year': 2020, 'school_name': 'Newbotics Community Robotics', 'state_prov': 'Ontario', 'team_number': 8349, 'website': 'https://newbotics.org'}),
#  Team({'address': None, 'city': 'Toronto', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc8884', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Stone's Throw Design Inc./Deloitte Digital /Onyen ESG/PrintPOP/NSS Foundation/NSS School Council/Northern Student Affairs Council/TDSB/Northern Secondary School&Northern Secondary School", 'nickname': 'Knight Owls', 'postal_code': None, 'rookie_year': 2022, 'school_name': 'Northern Secondary School', 'state_prov': 'Ontario', 'team_number': 8884, 'website': None}),
#  Team({'address': None, 'city': 'Hamilton', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc9062', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': "Columbia International College/London North Rotary Club/Thomas Steele/FRC 6336: Javawockies/Argosy Foundation's New Team Grant/FIRST Canada/FRC 5406: Celt-X/NorthPoint Powder Coating/FRC 4039: Makeshift Robotics/Carbon Noir Customs/Family & Friends &Columbia International College", 'nickname': 'Critical Circuits', 'postal_code': None, 'rookie_year': 2023, 'school_name': 'Columbia International College', 'state_prov': 'Ontario', 'team_number': 9062, 'website': None}),
#  Team({'address': None, 'city': 'Oakville', 'country': 'Canada', 'gmaps_place_id': None, 'gmaps_url': None, 'key': 'frc9098', 'lat': None, 'lng': None, 'location_name': None, 'motto': None, 'name': 'FIRST Canada/FIRST/HATCH/Romag Contracting Ltd/Red Chillie/Interac Corp/Halton Catholic District School Board&St. Ignatius of Loyola Catholic Secondary School', 'nickname': 'FireHawks', 'postal_code': None, 'rookie_year': 2023, 'school_name': 'St. Ignatius of Loyola Catholic Secondary School', 'state_prov': 'Ontario', 'team_number': 9098, 'website': None})]

# %%
# dict3 = {}
# for i in tba.event_teams(event):
#     team_key = i['key']
#     if i['postal_code'] is not None:
#         dict3[team_key] = i['postal_code'].upper().replace(" ", "")
#     else:
#         dict3[team_key] = i['postal_code']

# # dict3['frc8884'] = 'M4P2L5'
# # dict3['frc9062'] = 'L8S4P3'
# # dict3['frc9098'] = 'L6M1S2'

# # dict3['frc8729'] = 'K2W0C9'
# # dict3['frc8764'] = 'L3T4N4'
# # dict3['frc9263'] = 'L7T1E5'
        
# dict3
# Out:
# {'frc1114': 'L2N2Z7',
#  'frc1285': 'L5V1N6',
#  'frc1310': 'M6S4A3',
#  'frc1325': 'L5R3N9',
#  'frc1334': 'L6J3L6',
#  'frc2013': 'L0M1S0',
#  'frc2386': 'L7S1K4',
#  'frc2609': 'N1H5H7',
#  'frc2706': 'K0A1L0',
#  'frc2708': 'K7L3S7',
#  'frc3739': 'N6H1V4',
#  'frc4039': 'L8S2G7',
#  'frc4069': 'P3E2P8',
#  'frc4343': 'L4G1J5',
#  'frc4678': 'N0B1M0',
#  'frc4688': 'N0R1A0',
#  'frc4903': 'N9E1J2',
#  'frc4907': 'N5R3C2',
#  'frc4917': 'N3B1K2',
#  'frc4920': 'N0R1A0',
#  'frc4946': 'L7E3V8',
#  'frc5024': 'N6B1W5',
#  'frc5036': 'M1E1P5',
#  'frc5596': 'M1V3S8',
#  'frc5870': 'N6G2C3',
#  'frc5885': 'N9A6Z6',
#  'frc610': 'M2L1A2',
#  'frc6378': 'L5M7E6',
#  'frc6854': 'N5X1L8',
#  'frc6864': 'P1P1X7',
#  'frc6865': 'P0P1G0',
#  'frc6987': 'K0M1N0',
#  'frc7476': 'K2K2B6',
#  'frc7690': 'L4C3S3',
#  'frc7722': 'N2N3B9',
#  'frc7757': 'N4K1X2',
#  'frc865': 'M6P3E3',
#  'frc8729': 'K2W0C9',
#  'frc8764': 'L3T4N4',
#  'frc9263': 'L7T1E5'}

# %%
# dict4 = {}
# for key, value in dict3.items():
#     team_key = key
#     if value is not None:
#         time.sleep(random.randint(14, 37)/19)
#         with urllib.request.urlopen('http://represent.opennorth.ca/postcodes/' + value) as url:
#             data = json.load(url)
#         ind = 0
#         right = 0
#         while right == 0:
#             if data['boundaries_centroid'][ind]['url'][:40] == '/boundaries/federal-electoral-districts/':
#                 right = 1
#             else:
#                 ind += 1
#         dict4[team_key] = data['boundaries_centroid'][ind]['name']       
# dict4
# Out:
# {'frc1114': 'St. Catharines',
#  'frc1285': 'Mississauga Centre',
#  'frc1310': 'Parkdale—High Park',
#  'frc1325': 'Mississauga—Malton',
#  'frc1334': 'Oakville',
#  'frc2013': 'Simcoe—Grey',
#  'frc2386': 'Burlington',
#  'frc2609': 'Guelph',
#  'frc2706': 'Kanata—Carleton',
#  'frc2708': 'Kingston and the Islands',
#  'frc3739': 'London West',
#  'frc4039': 'Hamilton West—Ancaster—Dundas',
#  'frc4069': 'Sudbury',
#  'frc4343': 'Newmarket—Aurora',
#  'frc4678': 'Kitchener—Conestoga',
#  'frc4688': 'Essex',
#  'frc4903': 'Windsor West',
#  'frc4907': 'Elgin—Middlesex—London',
#  'frc4917': 'Kitchener—Conestoga',
#  'frc4920': 'Essex',
#  'frc4946': 'Dufferin—Caledon',
#  'frc5024': 'London North Centre',
#  'frc5036': 'Scarborough—Guildwood',
#  'frc5596': 'Scarborough—Agincourt',
#  'frc5870': 'London West',
#  'frc5885': 'Essex',
#  'frc610': 'Don Valley West',
#  'frc6378': 'Mississauga—Erin Mills',
#  'frc6854': 'London North Centre',
#  'frc6864': 'Parry Sound—Muskoka',
#  'frc6865': 'Algoma—Manitoulin—Kapuskasing',
#  'frc6987': 'Haliburton—Kawartha Lakes—Brock',
#  'frc7476': 'Kanata—Carleton',
#  'frc7690': 'Richmond Hill',
#  'frc7722': 'Kitchener—Conestoga',
#  'frc7757': 'Bruce—Grey—Owen Sound',
#  'frc865': 'Parkdale—High Park',
#  'frc8729': 'Kanata—Carleton',
#  'frc8764': 'Thornhill',
#  'frc9263': 'Burlington'}

# %%
# dict4
# Out:
# {'frc1241': 'Mississauga Centre',
#  'frc1310': 'Parkdale—High Park',
#  'frc1325': 'Mississauga—Malton',
#  'frc1334': 'Oakville',
#  'frc1360': 'Oakville',
#  'frc1374': 'Oakville',
#  'frc188': 'Scarborough—Guildwood',
#  'frc2056': 'Hamilton East—Stoney Creek',
#  'frc2200': 'Burlington',
#  'frc2386': 'Burlington',
#  'frc2609': 'Guelph',
#  'frc4015': 'Mississauga—Malton',
#  'frc4343': 'Newmarket—Aurora',
#  'frc4992': 'Milton',
#  'frc5406': 'Flamborough—Glanbrook',
#  'frc6135': 'Davenport',
#  'frc6140': 'Scarborough—Rouge Park',
#  'frc6378': 'Mississauga—Erin Mills',
#  'frc6854': 'London North Centre',
#  'frc6865': 'Algoma—Manitoulin—Kapuskasing',
#  'frc6975': 'Scarborough Southwest',
#  'frc6978': 'Niagara Centre',
#  'frc6992': 'Sarnia—Lambton',
#  'frc7022': 'Cambridge',
#  'frc7058': 'Lambton—Kent—Middlesex',
#  'frc7200': 'Simcoe—Grey',
#  'frc7509': 'Brantford—Brant',
#  'frc7520': 'Willowdale',
#  'frc7623': 'Hamilton West—Ancaster—Dundas',
#  'frc7659': 'Mississauga—Lakeshore',
#  'frc7722': 'Kitchener—Conestoga'}

# %%
tba.event_oprs(event)['oprs']
# Out:
# {'frc1241': 59.66182169848582,
#  'frc1310': 47.53995267094184,
#  'frc1325': 76.23922325736116,
#  'frc1334': 27.637977074521743,
#  'frc1360': 33.37891181111269,
#  'frc1374': 28.009062355220706,
#  'frc188': 12.357624294464145,
#  'frc2056': 87.94829059957391,
#  'frc2200': 54.358232814979885,
#  'frc2386': 25.092241734421727,
#  'frc2609': 50.22288002311297,
#  'frc4015': 6.175230877167696,
#  'frc4343': 39.229257188161235,
#  'frc4992': 24.807267050015668,
#  'frc5406': 58.99923248217294,
#  'frc6135': 17.12839948500588,
#  'frc6140': 35.75788778238099,
#  'frc6378': 27.95572374241997,
#  'frc6854': 17.63729527057022,
#  'frc6865': 18.531667632567952,
#  'frc6975': 10.736317903529827,
#  'frc6978': 32.30641370707619,
#  'frc6992': 20.88757724657893,
#  'frc7022': 27.662784052547323,
#  'frc7058': 27.911973104464703,
#  'frc7200': 33.21879608721528,
#  'frc7509': 27.214023234193174,
#  'frc7520': 17.971919035993864,
#  'frc7623': 19.565578287337004,
#  'frc7659': 21.875856982923995,
#  'frc7722': 23.297009756154978,
#  'frc8764': 21.23989394802318,
#  'frc8765': 14.832971975250537,
#  'frc8884': 38.53853094346015,
#  'frc9062': 19.60692967807293,
#  'frc9262': 4.54857754585165}
